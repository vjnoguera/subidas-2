# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
X = [  1,   5,   3,   5,  10,  14,  15,  18,  14,  20,  22,  20,  25,
        25,  32,  31,  34,  37,  39,  42,  43,  42,  48,  48,  51,  52,
        51,  53,  60,  56,  59,  65,  66,  67,  72,  71,  76,  78,  79,
        82,  83,  81,  83,  84,  87,  94,  93,  94,  95, 102]

# %%
X = np.array(X)
X
# Out:
# array([  1,   5,   3,   5,  10,  14,  15,  18,  14,  20,  22,  20,  25,
#         25,  32,  31,  34,  37,  39,  42,  43,  42,  48,  48,  51,  52,
#         51,  53,  60,  56,  59,  65,  66,  67,  72,  71,  76,  78,  79,
#         82,  83,  81,  83,  84,  87,  94,  93,  94,  95, 102])

# %%
Y = [ 12,  16,  17,   7,  20,   3,  10,  19,   8,  14,  31,  17,  14,
        19,  20,  42,  32,  26,  35,  50,  51,  48,  49,  59,  58,  46,
        54,  63,  55,  48,  58,  74,  56,  71,  72,  68,  72,  85,  80,
        92,  89,  73,  85,  86, 100,  83,  92, 100,  97,  91]

# %%
Y = np.array(Y)
Y
# Out:
# array([ 12,  16,  17,   7,  20,   3,  10,  19,   8,  14,  31,  17,  14,
#         19,  20,  42,  32,  26,  35,  50,  51,  48,  49,  59,  58,  46,
#         54,  63,  55,  48,  58,  74,  56,  71,  72,  68,  72,  85,  80,
#         92,  89,  73,  85,  86, 100,  83,  92, 100,  97,  91])

# %%
X_1 = np.c_[np.ones((50, 1)), X]
X_1
# Out:
# array([[  1.,   1.],
#        [  1.,   5.],
#        [  1.,   3.],
#        [  1.,   5.],
#        [  1.,  10.],
#        [  1.,  14.],
#        [  1.,  15.],
#        [  1.,  18.],
#        [  1.,  14.],
#        [  1.,  20.],
#        [  1.,  22.],
#        [  1.,  20.],
#        [  1.,  25.],
#        [  1.,  25.],
#        [  1.,  32.],
#        [  1.,  31.],
#        [  1.,  34.],
#        [  1.,  37.],
#        [  1.,  39.],
#        [  1.,  42.],
#        [  1.,  43.],
#        [  1.,  42.],
#        [  1.,  48.],
#        [  1.,  48.],
#        [  1.,  51.],
#        [  1.,  52.],
#        [  1.,  51.],
#        [  1.,  53.],
#        [  1.,  60.],
#        [  1.,  56.],
#        [  1.,  59.],
#        [  1.,  65.],
#        [  1.,  66.],
#        [  1.,  67.],
#        [  1.,  72.],
#        [  1.,  71.],
#        [  1.,  76.],
#        [  1.,  78.],
#        [  1.,  79.],
#        [  1.,  82.],
#        [  1.,  83.],
#        [  1.,  81.],
#        [  1.,  83.],
# ...

# %%
best_W = np.linalg.inv(X_1.T.dot(X_1)).dot(X_1.T).dot(Y)
best_W
# Out:
# array([1.78117049, 0.98058626])

# %%
# from IPython.display import clear_output
# m = 0
# c = 0
# lr = 0.00001
# # y = m*+c
# error = sum((y - (m*X + c))**2)/len(Y)
# for n in range(200):
#     clear_output(wait=True)
#     # y = m*X+c
   
#     dm = 2/len(Y)*sum((Y-(m*X+c))*(-X))
#     dc = 2/len(Y)*sum((Y-(m*X+c))*(-1))
#     m=m-dm*lr
#     c=c-dc*lr
#     fig =plt.figure()
#     plt.scatter(x = X, y = Y)
#     plt.plot(X, m*X+c,"r")
#     plt.title(f"iter: {n}, error:{sum((Y - (m*X + c))**2)/len(Y)},m: {m}, c: {c}" )
#     plt.show()
