# %% [markdown]
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
#
# # Ejercicio Regression Tree
# Son datos de temperaturas tomados de la ciudad de Seattle. El objetivo es intentar predecir lo mejor posible la máxima temperatura (columna `actual`) que alcanzaremos al día siguiente. Para ello contaremos con temperaturas de los dos días anteriores, históricos de máximas temperaturas y un amigo bastante chapas que te da su predicción del tiempo cada día.
#
# **Resumen de datos**:
# * year: 2016 for all data points
# * month: number for month of the year
# * day: number for day of the year
# * week: day of the week as a character string
# * temp_2: max temperature 2 days prior
# * temp_1: max temperature 1 day prior
# * average: historical average max temperature
# * actual: max temperature measurement
# * friend: your friend’s prediction, a random number between 20 below the average and 20 above the average
#
#
# ### 1. Importa el csv "temps.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# carga los datos de data/temps.csv
df = pd.read_csv(r"C:\Users\Victor\Desktop\Data2 - copia\3-Machine_Learning\1-Supervisado\3-Reg&Class\5-Decision_Trees\ejercicio\data\temps.csv")
df
# Out:
#      year  month  day   week  temp_2  temp_1  average  actual  forecast_noaa  \
# 0    2016      1    1    Fri      45      45     45.6      45             43
# 1    2016      1    2    Sat      44      45     45.7      44             41
# 2    2016      1    3    Sun      45      44     45.8      41             43
# 3    2016      1    4    Mon      44      41     45.9      40             44
# 4    2016      1    5   Tues      41      40     46.0      44             46
# ..    ...    ...  ...    ...     ...     ...      ...     ...            ...
# 343  2016     12   27   Tues      42      42     45.2      47             41
# 344  2016     12   28    Wed      42      47     45.3      48             41
# 345  2016     12   29  Thurs      47      48     45.3      48             43
# 346  2016     12   30    Fri      48      48     45.4      57             44
# 347  2016     12   31    Sat      48      57     45.5      40             42
#
#      forecast_acc  forecast_under  friend
# 0              50              44      29
# 1              50              44      61
# 2              46              47      56
# 3              48              46      53
# 4              46              46      41
# ..            ...             ...     ...
# 343            50              47      47
# 344            49              44      58
# 345            50              45      65
# 346            46              44      42
# 347            48              47      57
#
# [348 rows x 12 columns]

# %%
# carga los datos de data/temps.csv
# Out:
#    year  month  day  week  temp_2  temp_1  average  actual  forecast_noaa  \
# 0  2016      1    1   Fri      45      45     45.6      45             43
# 1  2016      1    2   Sat      44      45     45.7      44             41
# 2  2016      1    3   Sun      45      44     45.8      41             43
# 3  2016      1    4   Mon      44      41     45.9      40             44
# 4  2016      1    5  Tues      41      40     46.0      44             46
#
#    forecast_acc  forecast_under  friend
# 0            50              44      29
# 1            50              44      61
# 2            46              47      56
# 3            48              46      53
# 4            46              46      41

# %% [markdown]
# ### 2. Lidia con las variables categóricas del dataset

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348 entries, 0 to 347
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            348 non-null    int64
#  1   month           348 non-null    int64
#  2   day             348 non-null    int64
#  3   week            348 non-null    object
#  4   temp_2          348 non-null    int64
#  5   temp_1          348 non-null    int64
#  6   average         348 non-null    float64
#  7   actual          348 non-null    int64
#  8   forecast_noaa   348 non-null    int64
#  9   forecast_acc    348 non-null    int64
#  10  forecast_under  348 non-null    int64
#  11  friend          348 non-null    int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 32.8+ KB

# %%
# decribe
df.describe()
# Out:
#          year       month         day      temp_2      temp_1     average  \
# count   348.0  348.000000  348.000000  348.000000  348.000000  348.000000
# mean   2016.0    6.477011   15.514368   62.652299   62.701149   59.760632
# std       0.0    3.498380    8.772982   12.165398   12.120542   10.527306
# min    2016.0    1.000000    1.000000   35.000000   35.000000   45.100000
# 25%    2016.0    3.000000    8.000000   54.000000   54.000000   49.975000
# 50%    2016.0    6.000000   15.000000   62.500000   62.500000   58.200000
# 75%    2016.0   10.000000   23.000000   71.000000   71.000000   69.025000
# max    2016.0   12.000000   31.000000  117.000000  117.000000   77.400000
#
#            actual  forecast_noaa  forecast_acc  forecast_under      friend
# count  348.000000     348.000000    348.000000      348.000000  348.000000
# mean    62.543103      57.238506     62.373563       59.772989   60.034483
# std     11.794146      10.605746     10.549381       10.705256   15.626179
# min     35.000000      41.000000     46.000000       44.000000   28.000000
# 25%     54.000000      48.000000     53.000000       50.000000   47.750000
# 50%     62.500000      56.000000     61.000000       58.000000   60.000000
# 75%     71.000000      66.000000     72.000000       69.000000   71.000000
# max     92.000000      77.000000     82.000000       79.000000   95.000000

# %%
# valores unicos de la columna week
df["week"].unique()
# Out:
# array(['Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs'], dtype=object)

# %%
# valores de la columna week
df.loc[:,"week"].values
# Out:
# array(['Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Tues', 'Sun', 'Tues', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat'], dtype=object)

# %%
# Out:
# array(['Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Tues', 'Sun', 'Tues', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Mon', 'Tues',
#        'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs',
#        'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat',
#        'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed',
#        'Thurs', 'Fri', 'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri',
#        'Sat', 'Sun', 'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun',
#        'Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat'], dtype=object)

# %% [markdown]
# ESTO ES UN CODIGO PARA CAMBIAR CATEGORIAS A VALORES DE FORMA AUTOMATICA. ESTO COGE TODOS ESOS VALORES UNICOS DE WEEK Y LES ASIGNA UN NUMERO A CADA UNO. OJO!! NO TIENE PORQUE SER LUNES 1, MARTES 2, MIERCOLES 3 AND SO ON

# %%
# usamos todos los datos (sin train ni test) pero esto habria que negociarlo...
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['week'])
le.transform(df['week'])
# Out:
# array([0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0,
#        2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 1,
#        5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 5, 6, 4, 0, 2, 3, 1, 5, 6,
#        4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4,
#        0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0,
#        2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2,
#        3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3,
#        1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1,
#        5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5,
#        6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6,
#        4, 0, 2, 3, 1, 5, 5, 3, 5, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4,
#        0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0,
#        2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2,
#        1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1,
#        5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5,
#        6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2, 3, 1, 5, 6, 4, 0, 2])

# %% [markdown]
# OTRA FORMA SERIA HACER COLUMNAS DUMMIES:

# %%
pd.get_dummies(df['week'])
# Out:
#        Fri    Mon    Sat    Sun  Thurs   Tues    Wed
# 0     True  False  False  False  False  False  False
# 1    False  False   True  False  False  False  False
# 2    False  False  False   True  False  False  False
# 3    False   True  False  False  False  False  False
# 4    False  False  False  False  False   True  False
# ..     ...    ...    ...    ...    ...    ...    ...
# 343  False  False  False  False  False   True  False
# 344  False  False  False  False  False  False   True
# 345  False  False  False  False   True  False  False
# 346   True  False  False  False  False  False  False
# 347  False  False   True  False  False  False  False
#
# [348 rows x 7 columns]

# %% [markdown]
# PERO AL FINAL, USAMOS LA FORMA "MANUAL"

# %%
#Reemplaza el valor de la columna week con un diccionario
my_dict = {'Mon':0,'Tues':1,'Wed':2,'Thurs':3,'Fri':4,'Sat':5,'Sun':6}

df['week'] = df['week'].replace(my_dict)
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_13120\2500110800.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['week'] = df['week'].replace(my_dict)

# %%
df
# Out:
#      year  month  day  week  temp_2  temp_1  average  actual  forecast_noaa  \
# 0    2016      1    1     4      45      45     45.6      45             43
# 1    2016      1    2     5      44      45     45.7      44             41
# 2    2016      1    3     6      45      44     45.8      41             43
# 3    2016      1    4     0      44      41     45.9      40             44
# 4    2016      1    5     1      41      40     46.0      44             46
# ..    ...    ...  ...   ...     ...     ...      ...     ...            ...
# 343  2016     12   27     1      42      42     45.2      47             41
# 344  2016     12   28     2      42      47     45.3      48             41
# 345  2016     12   29     3      47      48     45.3      48             43
# 346  2016     12   30     4      48      48     45.4      57             44
# 347  2016     12   31     5      48      57     45.5      40             42
#
#      forecast_acc  forecast_under  friend
# 0              50              44      29
# 1              50              44      61
# 2              46              47      56
# 3              48              46      53
# 4              46              46      41
# ..            ...             ...     ...
# 343            50              47      47
# 344            49              44      58
# 345            50              45      65
# 346            46              44      42
# 347            48              47      57
#
# [348 rows x 12 columns]

# %% [markdown]
# SI LOS DATOS SON MUY VARIABLES, A VECES INTERESA MODIFICAR UNA COLUMNA POR UN AGREGADO.
# OS ACORDAIS DE LOS AGREGADOS? AQUI SE PIDE AGREGAR TEMPERATURA POR MES USANDO LA MEDIA:

# %%
months_g = df.groupby("month")[["temp_1"]].mean().reset_index()
months_g
# Out:
#     month     temp_1
# 0       1  49.677419
# 1       2  54.115385
# 2       3  56.483871
# 3       4  66.433333
# 4       5  68.838710
# 5       6  73.233333
# 6       7  76.225806
# 7       8  77.947368
# 8       9  70.428571
# 9      10  63.900000
# 10     11  56.966667
# 11     12  43.741935

# %%
months_g = ...?
months_g
# Out:
#     month     temp_1
# 0       1  49.677419
# 1       2  54.115385
# 2       3  56.483871
# 3       4  66.433333
# 4       5  68.838710
# 5       6  73.233333
# 6       7  76.225806
# 7       8  77.947368
# 8       9  70.428571
# 9      10  63.900000
# 10     11  56.966667
# 11     12  43.741935

# %% [markdown]
# ESTO LO DEJO. LO QUE HACEMOS ES UN JOIN PARA AGREGAR LA COLUMNA DE LA MEDIA MENSUAL AL DATO ORIGINAL
# RECORDAD QUE NOS GENERARA UNA COLUMNA TEMP_1_X Y TEMP_1_Y POR QUE EL NOMBRE ESTA REPE

# %%
df = df.merge(months_g, on='month')

# %%
import seaborn as sns
sns.pairplot(df[['actual','temp_1_y']])

# %%
df1 = df.drop("year", axis = 1)
df1
# Out:
#      month  day  week  temp_2  temp_1_x  average  actual  forecast_noaa  \
# 0        1    1     4      45        45     45.6      45             43
# 1        1    2     5      44        45     45.7      44             41
# 2        1    3     6      45        44     45.8      41             43
# 3        1    4     0      44        41     45.9      40             44
# 4        1    5     1      41        40     46.0      44             46
# ..     ...  ...   ...     ...       ...      ...     ...            ...
# 343     12   27     1      42        42     45.2      47             41
# 344     12   28     2      42        47     45.3      48             41
# 345     12   29     3      47        48     45.3      48             43
# 346     12   30     4      48        48     45.4      57             44
# 347     12   31     5      48        57     45.5      40             42
#
#      forecast_acc  forecast_under  friend   temp_1_y
# 0              50              44      29  49.677419
# 1              50              44      61  49.677419
# 2              46              47      56  49.677419
# 3              48              46      53  49.677419
# 4              46              46      41  49.677419
# ..            ...             ...     ...        ...
# 343            50              47      47  43.741935
# 344            49              44      58  43.741935
# 345            50              45      65  43.741935
# 346            46              44      42  43.741935
# 347            48              47      57  43.741935
#
# [348 rows x 12 columns]

# %%
df1.corr()
# Out:
#                    month       day      week    temp_2  temp_1_x   average  \
# month           1.000000 -0.000412 -0.004352  0.047651  0.032664  0.120806
# day            -0.000412  1.000000  0.010433 -0.046194 -0.000691 -0.021136
# week           -0.004352  0.010433  1.000000  0.011480 -0.012466 -0.002848
# temp_2          0.047651 -0.046194  0.011480  1.000000  0.857800  0.821560
# temp_1_x        0.032664 -0.000691 -0.012466  0.857800  1.000000  0.819328
# average         0.120806 -0.021136 -0.002848  0.821560  0.819328  1.000000
# actual          0.004529 -0.021675 -0.031188  0.805835  0.877880  0.848365
# forecast_noaa   0.131141 -0.021393  0.010827  0.813134  0.810672  0.990340
# forecast_acc    0.127436 -0.030605  0.001928  0.817374  0.815162  0.990705
# forecast_under  0.119786 -0.013727 -0.006685  0.819576  0.815943  0.994373
# friend          0.048145  0.024592 -0.005890  0.583758  0.541282  0.689278
# temp_1_y        0.038228 -0.033155 -0.011040  0.848433  0.854456  0.955213
#
#                   actual  forecast_noaa  forecast_acc  forecast_under  \
# month           0.004529       0.131141      0.127436        0.119786
# day            -0.021675      -0.021393     -0.030605       -0.013727
# week           -0.031188       0.010827      0.001928       -0.006685
# temp_2          0.805835       0.813134      0.817374        0.819576
# temp_1_x        0.877880       0.810672      0.815162        0.815943
# average         0.848365       0.990340      0.990705        0.994373
# actual          1.000000       0.838639      0.842135        0.838946
# forecast_noaa   0.838639       1.000000      0.979863        0.985670
# forecast_acc    0.842135       0.979863      1.000000        0.983910
# forecast_under  0.838946       0.985670      0.983910        1.000000
# friend          0.569145       0.669221      0.696054        0.691177
# temp_1_y        0.876224       0.945439      0.944135        0.946886
#
#                   friend  temp_1_y
# month           0.048145  0.038228
# day             0.024592 -0.033155
# week           -0.005890 -0.011040
# temp_2          0.583758  0.848433
# temp_1_x        0.541282  0.854456
# average         0.689278  0.955213
# actual          0.569145  0.876224
# forecast_noaa   0.669221  0.945439
# forecast_acc    0.696054  0.944135
# forecast_under  0.691177  0.946886
# friend          1.000000  0.643025
# temp_1_y        0.643025  1.000000

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df1.corr(), annot= True)
# Out:
# <Axes: >

# %%
# HEATMAP

# %% [markdown]
# ### 3. Divide en train y test

# %% [markdown]
# HACEMOS UN TRAIN TEST SPLIT DONDE QUITAMOS LAS COLUMNAS ['year','day','week'] Y USAMOS ACTUAL COMO TARGET

# %%
df2 = df1.drop(["day","week"],axis=1)
df2
# Out:
#      month  temp_2  temp_1_x  average  actual  forecast_noaa  forecast_acc  \
# 0        1      45        45     45.6      45             43            50
# 1        1      44        45     45.7      44             41            50
# 2        1      45        44     45.8      41             43            46
# 3        1      44        41     45.9      40             44            48
# 4        1      41        40     46.0      44             46            46
# ..     ...     ...       ...      ...     ...            ...           ...
# 343     12      42        42     45.2      47             41            50
# 344     12      42        47     45.3      48             41            49
# 345     12      47        48     45.3      48             43            50
# 346     12      48        48     45.4      57             44            46
# 347     12      48        57     45.5      40             42            48
#
#      forecast_under  friend   temp_1_y
# 0                44      29  49.677419
# 1                44      61  49.677419
# 2                47      56  49.677419
# 3                46      53  49.677419
# 4                46      41  49.677419
# ..              ...     ...        ...
# 343              47      47  43.741935
# 344              44      58  43.741935
# 345              45      65  43.741935
# 346              44      42  43.741935
# 347              47      57  43.741935
#
# [348 rows x 10 columns]

# %%
X = df2.drop(["actual"],axis=1)
X
# Out:
#      month  temp_2  temp_1_x  average  forecast_noaa  forecast_acc  \
# 0        1      45        45     45.6             43            50
# 1        1      44        45     45.7             41            50
# 2        1      45        44     45.8             43            46
# 3        1      44        41     45.9             44            48
# 4        1      41        40     46.0             46            46
# ..     ...     ...       ...      ...            ...           ...
# 343     12      42        42     45.2             41            50
# 344     12      42        47     45.3             41            49
# 345     12      47        48     45.3             43            50
# 346     12      48        48     45.4             44            46
# 347     12      48        57     45.5             42            48
#
#      forecast_under  friend   temp_1_y
# 0                44      29  49.677419
# 1                44      61  49.677419
# 2                47      56  49.677419
# 3                46      53  49.677419
# 4                46      41  49.677419
# ..              ...     ...        ...
# 343              47      47  43.741935
# 344              44      58  43.741935
# 345              45      65  43.741935
# 346              44      42  43.741935
# 347              47      57  43.741935
#
# [348 rows x 9 columns]

# %%
y = df2["actual"]
y
# Out:
# 0      45
# 1      44
# 2      41
# 3      40
# 4      44
#        ..
# 343    47
# 344    48
# 345    48
# 346    57
# 347    40
# Name: actual, Length: 348, dtype: int64

# %%
# train_test_split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.20, random_state = 42)

# %%
print("X_train", X_train.shape)
print("X_train", X_test.shape)
print("X_train", y_train.shape)
print("X_train", y_test.shape)
# Out:
# X_train (278, 9)
# X_train (70, 9)
# X_train (278,)
# X_train (70,)

# %% [markdown]
# ### 4. Entrena el modelo

# %%
from sklearn.tree import DecisionTreeRegressor
# el modelo se llama dtr
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.feature_names_in_
# Out:
# array(['month', 'temp_2', 'temp_1_x', 'average', 'forecast_noaa',
#        'forecast_acc', 'forecast_under', 'friend', 'temp_1_y'],
#       dtype=object)

# %%
# Out:
# Index(['month', 'temp_2', 'temp_1_x', 'average', 'forecast_noaa',
#        'forecast_acc', 'forecast_under', 'friend', 'temp_1_y'],
#       dtype='object')

# %%
dtr.feature_importances_
# Out:
# array([0.01762013, 0.03015764, 0.76974714, 0.10303981, 0.01258647,
#        0.01558985, 0.02915223, 0.01358483, 0.0085219 ])

# %%
# muestra la feature importance del modelo
# Out:
# array([0.01864284, 0.02306268, 0.76979138, 0.09715291, 0.01512062,
#        0.02218712, 0.03053199, 0.0179435 , 0.00556695])

# %% [markdown]
# ### 5. Evaluación de tu modelo
# Calcula el coeficiente de determinación.
#
# Calcula el MAE, MAPE, MSE y RMSE.

# %%
y_pred = dtr.predict(X_test)
y_pred
# Out:
# array([79., 68., 57., 68., 76., 76., 71., 79., 71., 71., 68., 65., 39.,
#        60., 79., 55., 58., 57., 55., 65., 63., 55., 70., 55., 64., 49.,
#        66., 45., 60., 77., 66., 68., 56., 90., 73., 60., 51., 48., 74.,
#        40., 77., 57., 81., 40., 59., 75., 56., 87., 52., 39., 45., 39.,
#        63., 64., 75., 57., 55., 61., 60., 53., 60., 46., 60., 71., 71.,
#        57., 71., 67., 80., 39.])

# %%
y_pred = ...
y_pred
# Out:
# array([80., 68., 57., 64., 72., 76., 73., 79., 68., 81., 68., 67., 39.,
#        59., 78., 57., 63., 54., 55., 79., 63., 57., 70., 59., 64., 48.,
#        66., 45., 60., 77., 66., 64., 57., 88., 73., 60., 51., 51., 74.,
#        40., 77., 54., 81., 41., 58., 76., 55., 79., 52., 39., 40., 39.,
#        63., 64., 74., 61., 55., 61., 60., 57., 60., 46., 60., 71., 68.,
#        57., 71., 67., 80., 39.])

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
import numpy as np

print("Coeficiente determinación", r2_score(y_test, y_pred))
print("MAE", mean_absolute_error(y_test, y_pred))
print("MAPE", mean_absolute_percentage_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coeficiente determinación 0.6191165652767886
# MAE 5.8
# MAPE 0.09048476967795642
# MSE 53.25714285714286
# RMSE 7.297749163758841

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
import numpy as np

print("Coeficiente determinación", r2_score(y_test, y_pred))
print("MAE", mean_absolute_error(y_test, y_pred))
print("MAPE", mean_absolute_percentage_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coeficiente determinación 0.7207740270658431
# MAE 4.985714285714286
# MAPE 0.08014862331935532
# MSE 39.042857142857144
# RMSE 6.248428373827865

# %%
print("Coeficiente determinación", r2_score(y_train, dtr.predict(X_train)))
print("MAE", mean_absolute_error(y_train, dtr.predict(X_train)))
print("MAPE", mean_absolute_percentage_error(y_train, dtr.predict(X_train)))
print("MSE", mean_squared_error(y_train, dtr.predict(X_train)))
print("RMSE", np.sqrt(mean_squared_error(y_train, dtr.predict(X_train))))
# Out:
# Coeficiente determinación 1.0
# MAE 0.0
# MAPE 0.0
# MSE 0.0
# RMSE 0.0

# %%
print("Coeficiente determinación", r2_score(y_train, dtr.predict(X_train)))
print("MAE", mean_absolute_error(y_train, dtr.predict(X_train)))
print("MAPE", mean_absolute_percentage_error(y_train, dtr.predict(X_train)))
print("MSE", mean_squared_error(y_train, dtr.predict(X_train)))
print("RMSE", np.sqrt(mean_squared_error(y_train, dtr.predict(X_train))))
# Out:
# Coeficiente determinación 1.0
# MAE 0.0
# MAPE 0.0
# MSE 0.0
# RMSE 0.0

# %% [markdown]
# ### 6. Representa el árbol de decision

# %%
df2
# Out:
#      month  temp_2  temp_1_x  average  actual  forecast_noaa  forecast_acc  \
# 0        1      45        45     45.6      45             43            50
# 1        1      44        45     45.7      44             41            50
# 2        1      45        44     45.8      41             43            46
# 3        1      44        41     45.9      40             44            48
# 4        1      41        40     46.0      44             46            46
# ..     ...     ...       ...      ...     ...            ...           ...
# 343     12      42        42     45.2      47             41            50
# 344     12      42        47     45.3      48             41            49
# 345     12      47        48     45.3      48             43            50
# 346     12      48        48     45.4      57             44            46
# 347     12      48        57     45.5      40             42            48
#
#      forecast_under  friend   temp_1_y
# 0                44      29  49.677419
# 1                44      61  49.677419
# 2                47      56  49.677419
# 3                46      53  49.677419
# 4                46      41  49.677419
# ..              ...     ...        ...
# 343              47      47  43.741935
# 344              44      58  43.741935
# 345              45      65  43.741935
# 346              44      42  43.741935
# 347              47      57  43.741935
#
# [348 rows x 10 columns]

# %%
X_test.shape
# Out:
# (70, 9)

# %%
y_test.shape
# Out:
# (70,)

# %%
from sklearn.tree import DecisionTreeRegressor

# df3 = df2.drop("temp_1_y", axis = 1)
# df4 = df2
X = X_train # petal length and width
y = y_train

tree_clf = DecisionTreeRegressor()
tree_clf.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
import sklearn.tree 

# X_train.

plt.figure(figsize=(10,10))
sklearn.tree.plot_tree(tree_clf,
               feature_names=dtr.feature_names_in_,
               class_names=True,
               filled = True)
# Out:
# [Text(0.43533214890813254, 0.9705882352941176, 'temp_1_x <= 59.5\nsquared_error = 138.218\nsamples = 278\nvalue = 62.342'),
#  Text(0.17151418172690763, 0.9117647058823529, 'average <= 46.85\nsquared_error = 43.932\nsamples = 116\nvalue = 51.414'),
#  Text(0.06526104417670683, 0.8529411764705882, 'temp_1_x <= 44.5\nsquared_error = 19.984\nsamples = 32\nvalue = 43.375'),
#  Text(0.03614457831325301, 0.7941176470588235, 'actual <= 42.5\nsquared_error = 10.055\nsamples = 17\nvalue = 41.059'),
#  Text(0.020080321285140562, 0.7352941176470589, 'forecast_under <= 46.5\nsquared_error = 6.56\nsamples = 5\nvalue = 43.8'),
#  Text(0.012048192771084338, 0.6764705882352942, 'temp_1_x <= 43.5\nsquared_error = 2.667\nsamples = 3\nvalue = 42.0'),
#  Text(0.008032128514056224, 0.6176470588235294, 'forecast_noaa <= 48.0\nsquared_error = 1.0\nsamples = 2\nvalue = 41.0'),
#  Text(0.004016064257028112, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 40.0'),
#  Text(0.012048192771084338, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 42.0'),
#  Text(0.01606425702811245, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.028112449799196786, 0.6764705882352942, 'actual <= 41.5\nsquared_error = 0.25\nsamples = 2\nvalue = 46.5'),
#  Text(0.024096385542168676, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 47.0'),
#  Text(0.0321285140562249, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 46.0'),
#  Text(0.05220883534136546, 0.7352941176470589, 'temp_2 <= 39.5\nsquared_error = 7.076\nsamples = 12\nvalue = 39.917'),
#  Text(0.04417670682730924, 0.6764705882352942, 'forecast_noaa <= 46.5\nsquared_error = 3.556\nsamples = 3\nvalue = 36.333'),
#  Text(0.040160642570281124, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 39.0'),
#  Text(0.04819277108433735, 0.6176470588235294, 'squared_error = 0.0\nsamples = 2\nvalue = 35.0'),
#  Text(0.060240963855421686, 0.6764705882352942, 'actual <= 45.5\nsquared_error = 2.543\nsamples = 9\nvalue = 41.111'),
#  Text(0.05622489959839357, 0.6176470588235294, 'temp_1_x <= 41.0\nsquared_error = 1.688\nsamples = 8\nvalue = 40.75'),
#  Text(0.04618473895582329, 0.5588235294117647, 'forecast_under <= 42.5\nsquared_error = 1.0\nsamples = 4\nvalue = 40.0'),
#  Text(0.04216867469879518, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 41.0'),
#  Text(0.050200803212851405, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 39.0'),
#  Text(0.06626506024096386, 0.5588235294117647, 'average <= 45.7\nsquared_error = 1.25\nsamples = 4\nvalue = 41.5'),
#  Text(0.05823293172690763, 0.5, 'forecast_acc <= 45.5\nsquared_error = 0.25\nsamples = 2\nvalue = 42.5'),
#  Text(0.05421686746987952, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 43.0'),
#  Text(0.06224899598393574, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 42.0'),
#  Text(0.07429718875502007, 0.5, 'friend <= 46.71\nsquared_error = 0.25\nsamples = 2\nvalue = 40.5'),
#  Text(0.07028112449799197, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 40.0'),
#  Text(0.0783132530120482, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 41.0'),
#  Text(0.0642570281124498, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.09437751004016064, 0.7941176470588235, 'forecast_noaa <= 46.5\nsquared_error = 18.267\nsamples = 15\nvalue = 46.0'),
#  Text(0.09036144578313253, 0.7352941176470589, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.09839357429718876, 0.7352941176470589, 'temp_1_x <= 54.5\nsquared_error = 10.311\nsamples = 14\nvalue = 45.214'),
#  Text(0.09437751004016064, 0.6764705882352942, 'average <= 45.2\nsquared_error = 8.852\nsamples = 13\nvalue = 45.615'),
#  Text(0.08634538152610442, 0.6176470588235294, 'temp_1_x <= 47.0\nsquared_error = 6.25\nsamples = 2\nvalue = 42.5'),
#  Text(0.0823293172690763, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 40.0'),
#  Text(0.09036144578313253, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 45.0'),
#  Text(0.10240963855421686, 0.6176470588235294, 'actual <= 45.5\nsquared_error = 7.24\nsamples = 11\nvalue = 46.182'),
#  Text(0.09839357429718876, 0.5588235294117647, 'temp_2 <= 50.5\nsquared_error = 6.36\nsamples = 10\nvalue = 45.8'),
#  Text(0.09036144578313253, 0.5, 'average <= 45.45\nsquared_error = 5.609\nsamples = 8\nvalue = 45.125'),
#  Text(0.08634538152610442, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 48.0'),
#  Text(0.09437751004016064, 0.4411764705882353, 'forecast_under <= 63.0\nsquared_error = 3.806\nsamples = 6\nvalue = 44.167'),
#  Text(0.09036144578313253, 0.38235294117647056, 'forecast_under <= 57.0\nsquared_error = 0.4\nsamples = 5\nvalue = 45.0'),
#  Text(0.08634538152610442, 0.3235294117647059, 'forecast_under <= 46.0\nsquared_error = 0.188\nsamples = 4\nvalue = 45.25'),
#  Text(0.0823293172690763, 0.2647058823529412, 'squared_error = 0.0\nsamples = 3\nvalue = 45.0'),
#  Text(0.09036144578313253, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 46.0'),
#  Text(0.09437751004016064, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.09839357429718876, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 40.0'),
#  Text(0.10642570281124498, 0.5, 'forecast_acc <= 45.5\nsquared_error = 0.25\nsamples = 2\nvalue = 48.5'),
#  Text(0.10240963855421686, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.11044176706827309, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 48.0'),
#  Text(0.10642570281124498, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.10240963855421686, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 40.0'),
#  Text(0.27776731927710846, 0.8529411764705882, 'temp_1_x <= 55.5\nsquared_error = 19.059\nsamples = 84\nvalue = 54.476'),
#  Text(0.2203187751004016, 0.7941176470588235, 'average <= 49.25\nsquared_error = 10.728\nsamples = 54\nvalue = 52.444'),
#  Text(0.16741967871485944, 0.7352941176470589, 'temp_1_x <= 52.5\nsquared_error = 6.901\nsamples = 29\nvalue = 50.828'),
#  Text(0.14006024096385541, 0.6764705882352942, 'friend <= 46.71\nsquared_error = 7.27\nsamples = 23\nvalue = 51.348'),
#  Text(0.11847389558232932, 0.6176470588235294, 'forecast_under <= 40.0\nsquared_error = 2.889\nsamples = 3\nvalue = 48.333'),
#  Text(0.1144578313253012, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 46.0'),
#  Text(0.12248995983935743, 0.5588235294117647, 'temp_1_x <= 48.0\nsquared_error = 0.25\nsamples = 2\nvalue = 49.5'),
#  Text(0.11847389558232932, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.12650602409638553, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.16164658634538154, 0.6176470588235294, 'average <= 48.5\nsquared_error = 6.36\nsamples = 20\nvalue = 51.8'),
#  Text(0.14457831325301204, 0.5588235294117647, 'temp_2 <= 54.5\nsquared_error = 4.639\nsamples = 12\nvalue = 52.833'),
#  Text(0.13453815261044177, 0.5, 'actual <= 44.5\nsquared_error = 2.45\nsamples = 10\nvalue = 53.5'),
#  Text(0.12650602409638553, 0.4411764705882353, 'average <= 47.6\nsquared_error = 0.75\nsamples = 4\nvalue = 52.5'),
#  Text(0.12248995983935743, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 54.0'),
#  Text(0.13052208835341367, 0.38235294117647056, 'squared_error = 0.0\nsamples = 3\nvalue = 52.0'),
#  Text(0.142570281124498, 0.4411764705882353, 'forecast_noaa <= 49.0\nsquared_error = 2.472\nsamples = 6\nvalue = 54.167'),
#  Text(0.13855421686746988, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.1465863453815261, 0.38235294117647056, 'month <= 6.0\nsquared_error = 1.04\nsamples = 5\nvalue = 53.6'),
#  Text(0.13855421686746988, 0.3235294117647059, 'temp_2 <= 46.5\nsquared_error = 0.222\nsamples = 3\nvalue = 54.333'),
#  Text(0.13453815261044177, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.142570281124498, 0.2647058823529412, 'squared_error = 0.0\nsamples = 2\nvalue = 54.0'),
#  Text(0.15461847389558234, 0.3235294117647059, 'forecast_acc <= 48.0\nsquared_error = 0.25\nsamples = 2\nvalue = 52.5'),
#  Text(0.15060240963855423, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.15863453815261044, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.15461847389558234, 0.5, 'forecast_acc <= 47.0\nsquared_error = 2.25\nsamples = 2\nvalue = 49.5'),
#  Text(0.15060240963855423, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 48.0'),
#  Text(0.15863453815261044, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.178714859437751, 0.5588235294117647, 'forecast_noaa <= 49.5\nsquared_error = 4.938\nsamples = 8\nvalue = 50.25'),
#  Text(0.1746987951807229, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 46.0'),
#  Text(0.1827309236947791, 0.5, 'temp_2 <= 55.0\nsquared_error = 2.694\nsamples = 7\nvalue = 50.857'),
#  Text(0.178714859437751, 0.4411764705882353, 'forecast_acc <= 50.5\nsquared_error = 1.556\nsamples = 6\nvalue = 51.333'),
#  Text(0.1746987951807229, 0.38235294117647056, 'forecast_under <= 50.5\nsquared_error = 0.56\nsamples = 5\nvalue = 51.8'),
#  Text(0.1706827309236948, 0.3235294117647059, 'average <= 49.0\nsquared_error = 0.222\nsamples = 3\nvalue = 52.333'),
#  Text(0.16666666666666666, 0.2647058823529412, 'squared_error = 0.0\nsamples = 2\nvalue = 52.0'),
#  Text(0.1746987951807229, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.178714859437751, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 51.0'),
#  Text(0.1827309236947791, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.18674698795180722, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 48.0'),
#  Text(0.19477911646586346, 0.6764705882352942, 'temp_2 <= 48.5\nsquared_error = 0.472\nsamples = 6\nvalue = 48.833'),
#  Text(0.19076305220883535, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.19879518072289157, 0.6176470588235294, 'forecast_noaa <= 50.5\nsquared_error = 0.24\nsamples = 5\nvalue = 48.6'),
#  Text(0.19477911646586346, 0.5588235294117647, 'temp_2 <= 49.5\nsquared_error = 0.222\nsamples = 3\nvalue = 48.333'),
#  Text(0.19076305220883535, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.19879518072289157, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 48.0'),
#  Text(0.20281124497991967, 0.5588235294117647, 'squared_error = 0.0\nsamples = 2\nvalue = 49.0'),
#  Text(0.2732178714859438, 0.7352941176470589, 'temp_2 <= 57.5\nsquared_error = 8.618\nsamples = 25\nvalue = 54.32'),
#  Text(0.2512550200803213, 0.6764705882352942, 'forecast_noaa <= 57.5\nsquared_error = 7.628\nsamples = 20\nvalue = 53.65'),
#  Text(0.23142570281124497, 0.6176470588235294, 'forecast_noaa <= 51.5\nsquared_error = 6.851\nsamples = 17\nvalue = 54.176'),
#  Text(0.21084337349397592, 0.5588235294117647, 'forecast_under <= 63.0\nsquared_error = 2.188\nsamples = 4\nvalue = 51.75'),
#  Text(0.20682730923694778, 0.5, 'forecast_under <= 45.5\nsquared_error = 0.667\nsamples = 3\nvalue = 51.0'),
#  Text(0.20281124497991967, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.21084337349397592, 0.4411764705882353, 'average <= 50.55\nsquared_error = 0.25\nsamples = 2\nvalue = 51.5'),
#  Text(0.20682730923694778, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.21485943775100402, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.21485943775100402, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 54.0'),
#  Text(0.2520080321285141, 0.5588235294117647, 'temp_2 <= 54.5\nsquared_error = 5.917\nsamples = 13\nvalue = 54.923'),
#  Text(0.24096385542168675, 0.5, 'average <= 50.6\nsquared_error = 6.0\nsamples = 9\nvalue = 55.667'),
#  Text(0.23092369477911648, 0.4411764705882353, 'forecast_acc <= 50.5\nsquared_error = 5.44\nsamples = 5\nvalue = 54.6'),
#  Text(0.22289156626506024, 0.38235294117647056, 'average <= 50.15\nsquared_error = 0.889\nsamples = 3\nvalue = 56.333'),
#  Text(0.21887550200803213, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 57.0'),
#  Text(0.22690763052208834, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.2389558232931727, 0.38235294117647056, 'actual <= 48.5\nsquared_error = 1.0\nsamples = 2\nvalue = 52.0'),
#  Text(0.23493975903614459, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.2429718875502008, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.25100401606425704, 0.4411764705882353, 'temp_1_x <= 52.5\nsquared_error = 3.5\nsamples = 4\nvalue = 57.0'),
#  Text(0.2469879518072289, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.25502008032128515, 0.38235294117647056, 'forecast_under <= 46.0\nsquared_error = 0.667\nsamples = 3\nvalue = 56.0'),
#  Text(0.25100401606425704, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.25903614457831325, 0.3235294117647059, 'forecast_acc <= 53.5\nsquared_error = 0.25\nsamples = 2\nvalue = 55.5'),
#  Text(0.25502008032128515, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 56.0'),
#  Text(0.26305220883534136, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.26305220883534136, 0.5, 'month <= 2.5\nsquared_error = 1.688\nsamples = 4\nvalue = 53.25'),
#  Text(0.25903614457831325, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.26706827309236947, 0.4411764705882353, 'squared_error = 0.0\nsamples = 3\nvalue = 54.0'),
#  Text(0.2710843373493976, 0.6176470588235294, 'temp_2 <= 53.0\nsquared_error = 1.556\nsamples = 3\nvalue = 50.667'),
#  Text(0.26706827309236947, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.2751004016064257, 0.5588235294117647, 'average <= 53.35\nsquared_error = 0.25\nsamples = 2\nvalue = 51.5'),
#  Text(0.2710843373493976, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.2791164658634538, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.29518072289156627, 0.6764705882352942, 'actual <= 48.5\nsquared_error = 3.6\nsamples = 5\nvalue = 57.0'),
#  Text(0.28714859437751006, 0.6176470588235294, 'temp_2 <= 59.0\nsquared_error = 1.0\nsamples = 2\nvalue = 55.0'),
#  Text(0.28313253012048195, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 56.0'),
#  Text(0.29116465863453816, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 54.0'),
#  Text(0.3032128514056225, 0.6176470588235294, 'month <= 7.5\nsquared_error = 0.889\nsamples = 3\nvalue = 58.333'),
#  Text(0.2991967871485944, 0.5588235294117647, 'squared_error = 0.0\nsamples = 2\nvalue = 59.0'),
#  Text(0.3072289156626506, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.33521586345381527, 0.7941176470588235, 'actual <= 48.5\nsquared_error = 13.249\nsamples = 30\nvalue = 58.133'),
#  Text(0.3192771084337349, 0.7352941176470589, 'forecast_acc <= 47.5\nsquared_error = 1.76\nsamples = 10\nvalue = 55.2'),
#  Text(0.3152610441767068, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.3232931726907631, 0.6764705882352942, 'average <= 51.75\nsquared_error = 0.691\nsamples = 9\nvalue = 55.556'),
#  Text(0.3192771084337349, 0.6176470588235294, 'month <= 1.5\nsquared_error = 0.484\nsamples = 8\nvalue = 55.375'),
#  Text(0.3152610441767068, 0.5588235294117647, 'forecast_noaa <= 51.5\nsquared_error = 0.25\nsamples = 2\nvalue = 56.5'),
#  Text(0.3112449799196787, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.3192771084337349, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 56.0'),
#  Text(0.3232931726907631, 0.5588235294117647, 'squared_error = 0.0\nsamples = 6\nvalue = 55.0'),
#  Text(0.3273092369477912, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.35115461847389556, 0.7352941176470589, 'temp_2 <= 54.0\nsquared_error = 12.54\nsamples = 20\nvalue = 59.6'),
#  Text(0.3393574297188755, 0.6764705882352942, 'forecast_noaa <= 58.0\nsquared_error = 0.25\nsamples = 2\nvalue = 63.5'),
#  Text(0.3353413654618474, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.3433734939759036, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.3629518072289157, 0.6764705882352942, 'temp_2 <= 56.5\nsquared_error = 12.028\nsamples = 18\nvalue = 59.167'),
#  Text(0.3514056224899598, 0.6176470588235294, 'forecast_acc <= 54.5\nsquared_error = 2.667\nsamples = 3\nvalue = 55.0'),
#  Text(0.3473895582329317, 0.5588235294117647, 'forecast_under <= 50.0\nsquared_error = 1.0\nsamples = 2\nvalue = 56.0'),
#  Text(0.3433734939759036, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.3514056224899598, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.35542168674698793, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.3744979919678715, 0.6176470588235294, 'forecast_acc <= 54.5\nsquared_error = 9.733\nsamples = 15\nvalue = 60.0'),
#  Text(0.3634538152610442, 0.5588235294117647, 'forecast_noaa <= 52.0\nsquared_error = 2.889\nsamples = 3\nvalue = 63.333'),
#  Text(0.35943775100401604, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.3674698795180723, 0.5, 'friend <= 56.725\nsquared_error = 0.25\nsamples = 2\nvalue = 64.5'),
#  Text(0.3634538152610442, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.3714859437751004, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.3855421686746988, 0.5588235294117647, 'friend <= 56.725\nsquared_error = 7.972\nsamples = 12\nvalue = 59.167'),
#  Text(0.3815261044176707, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.3895582329317269, 0.5, 'temp_2 <= 60.5\nsquared_error = 2.083\nsamples = 11\nvalue = 59.909'),
#  Text(0.3795180722891566, 0.4411764705882353, 'month <= 7.5\nsquared_error = 1.5\nsamples = 4\nvalue = 59.0'),
#  Text(0.3755020080321285, 0.38235294117647056, 'forecast_noaa <= 62.0\nsquared_error = 0.222\nsamples = 3\nvalue = 59.667'),
#  Text(0.3714859437751004, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 60.0'),
#  Text(0.3795180722891566, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.38353413654618473, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.39959839357429716, 0.4411764705882353, 'forecast_noaa <= 59.5\nsquared_error = 1.673\nsamples = 7\nvalue = 60.429'),
#  Text(0.39156626506024095, 0.38235294117647056, 'average <= 55.3\nsquared_error = 0.222\nsamples = 3\nvalue = 61.667'),
#  Text(0.38755020080321284, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.39558232931726905, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 62.0'),
#  Text(0.40763052208835343, 0.38235294117647056, 'month <= 4.5\nsquared_error = 0.75\nsamples = 4\nvalue = 59.5'),
#  Text(0.4036144578313253, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 58.0'),
#  Text(0.41164658634538154, 0.3235294117647059, 'squared_error = 0.0\nsamples = 3\nvalue = 60.0'),
#  Text(0.6991501160893574, 0.9117647058823529, 'temp_1_x <= 67.5\nsquared_error = 58.991\nsamples = 162\nvalue = 70.167'),
#  Text(0.5088478915662651, 0.8529411764705882, 'forecast_acc <= 60.5\nsquared_error = 22.059\nsamples = 63\nvalue = 64.063'),
#  Text(0.4392570281124498, 0.7941176470588235, 'forecast_under <= 47.5\nsquared_error = 16.974\nsamples = 27\nvalue = 61.37'),
#  Text(0.41566265060240964, 0.7352941176470589, 'month <= 10.5\nsquared_error = 8.988\nsamples = 9\nvalue = 59.111'),
#  Text(0.40763052208835343, 0.6764705882352942, 'friend <= 65.167\nsquared_error = 2.889\nsamples = 6\nvalue = 57.667'),
#  Text(0.4036144578313253, 0.6176470588235294, 'average <= 50.1\nsquared_error = 1.76\nsamples = 5\nvalue = 58.2'),
#  Text(0.39959839357429716, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 56.0'),
#  Text(0.40763052208835343, 0.5588235294117647, 'forecast_under <= 40.5\nsquared_error = 0.688\nsamples = 4\nvalue = 58.75'),
#  Text(0.4036144578313253, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.41164658634538154, 0.5, 'month <= 6.0\nsquared_error = 0.222\nsamples = 3\nvalue = 58.333'),
#  Text(0.40763052208835343, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.41566265060240964, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 58.0'),
#  Text(0.41164658634538154, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.42369477911646586, 0.6764705882352942, 'forecast_under <= 39.5\nsquared_error = 8.667\nsamples = 3\nvalue = 62.0'),
#  Text(0.41967871485943775, 0.6176470588235294, 'average <= 53.3\nsquared_error = 1.0\nsamples = 2\nvalue = 64.0'),
#  Text(0.41566265060240964, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.42369477911646586, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.42771084337349397, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 58.0'),
#  Text(0.46285140562248994, 0.7352941176470589, 'average <= 56.45\nsquared_error = 17.139\nsamples = 18\nvalue = 62.5'),
#  Text(0.44377510040160645, 0.6764705882352942, 'forecast_noaa <= 56.5\nsquared_error = 19.938\nsamples = 8\nvalue = 64.75'),
#  Text(0.4357429718875502, 0.6176470588235294, 'temp_2 <= 64.5\nsquared_error = 2.25\nsamples = 4\nvalue = 60.5'),
#  Text(0.43172690763052207, 0.5588235294117647, 'temp_2 <= 61.5\nsquared_error = 0.222\nsamples = 3\nvalue = 59.667'),
#  Text(0.42771084337349397, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 60.0'),
#  Text(0.4357429718875502, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.4397590361445783, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.45180722891566266, 0.6176470588235294, 'actual <= 50.0\nsquared_error = 1.5\nsamples = 4\nvalue = 69.0'),
#  Text(0.44779116465863456, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.45582329317269077, 0.5588235294117647, 'forecast_noaa <= 60.0\nsquared_error = 0.222\nsamples = 3\nvalue = 68.333'),
#  Text(0.45180722891566266, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 68.0'),
#  Text(0.4598393574297189, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.4819277108433735, 0.6764705882352942, 'forecast_under <= 59.5\nsquared_error = 7.61\nsamples = 10\nvalue = 60.7'),
#  Text(0.4678714859437751, 0.6176470588235294, 'temp_2 <= 59.5\nsquared_error = 12.667\nsamples = 3\nvalue = 63.0'),
#  Text(0.463855421686747, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.4718875502008032, 0.5588235294117647, 'forecast_noaa <= 61.0\nsquared_error = 0.25\nsamples = 2\nvalue = 60.5'),
#  Text(0.4678714859437751, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.4759036144578313, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.4959839357429719, 0.6176470588235294, 'month <= 7.0\nsquared_error = 2.204\nsamples = 7\nvalue = 59.714'),
#  Text(0.4879518072289157, 0.5588235294117647, 'forecast_noaa <= 59.0\nsquared_error = 0.889\nsamples = 3\nvalue = 58.333'),
#  Text(0.4839357429718876, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.4919678714859438, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 59.0'),
#  Text(0.5040160642570282, 0.5588235294117647, 'average <= 58.1\nsquared_error = 0.688\nsamples = 4\nvalue = 60.75'),
#  Text(0.5, 0.5, 'forecast_under <= 68.5\nsquared_error = 0.25\nsamples = 2\nvalue = 61.5'),
#  Text(0.4959839357429719, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 62.0'),
#  Text(0.5040160642570282, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.5080321285140562, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 60.0'),
#  Text(0.5784387550200804, 0.7941176470588235, 'forecast_noaa <= 71.5\nsquared_error = 16.354\nsamples = 36\nvalue = 66.083'),
#  Text(0.5514558232931727, 0.7352941176470589, 'forecast_noaa <= 66.5\nsquared_error = 13.902\nsamples = 28\nvalue = 65.25'),
#  Text(0.5321285140562249, 0.6764705882352942, 'temp_1_x <= 65.5\nsquared_error = 12.667\nsamples = 9\nvalue = 67.667'),
#  Text(0.5281124497991968, 0.6176470588235294, 'average <= 61.95\nsquared_error = 6.688\nsamples = 8\nvalue = 66.75'),
#  Text(0.5200803212851406, 0.5588235294117647, 'temp_2 <= 62.0\nsquared_error = 6.222\nsamples = 3\nvalue = 64.667'),
#  Text(0.5160642570281124, 0.5, 'average <= 61.2\nsquared_error = 1.0\nsamples = 2\nvalue = 63.0'),
#  Text(0.5120481927710844, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.5200803212851406, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 62.0'),
#  Text(0.5240963855421686, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.536144578313253, 0.5588235294117647, 'average <= 64.35\nsquared_error = 2.8\nsamples = 5\nvalue = 68.0'),
#  Text(0.5321285140562249, 0.5, 'average <= 62.95\nsquared_error = 0.688\nsamples = 4\nvalue = 67.25'),
#  Text(0.5281124497991968, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 68.0'),
#  Text(0.536144578313253, 0.4411764705882353, 'actual <= 60.0\nsquared_error = 0.25\nsamples = 2\nvalue = 66.5'),
#  Text(0.5321285140562249, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.5401606425702812, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.5401606425702812, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.536144578313253, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.5707831325301205, 0.6764705882352942, 'forecast_under <= 59.0\nsquared_error = 10.41\nsamples = 19\nvalue = 64.105'),
#  Text(0.5562248995983936, 0.6176470588235294, 'temp_2 <= 76.5\nsquared_error = 5.44\nsamples = 5\nvalue = 60.6'),
#  Text(0.5522088353413654, 0.5588235294117647, 'forecast_under <= 51.5\nsquared_error = 2.75\nsamples = 4\nvalue = 61.5'),
#  Text(0.5481927710843374, 0.5, 'actual <= 62.5\nsquared_error = 1.0\nsamples = 2\nvalue = 60.0'),
#  Text(0.5441767068273092, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.5522088353413654, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.5562248995983936, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 63.0'),
#  Text(0.5602409638554217, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.5853413654618473, 0.6176470588235294, 'average <= 69.25\nsquared_error = 6.23\nsamples = 14\nvalue = 65.357'),
#  Text(0.5813253012048193, 0.5588235294117647, 'average <= 67.05\nsquared_error = 4.331\nsamples = 13\nvalue = 65.769'),
#  Text(0.570281124497992, 0.5, 'month <= 9.5\nsquared_error = 1.556\nsamples = 9\nvalue = 65.0'),
#  Text(0.5602409638554217, 0.4411764705882353, 'average <= 66.45\nsquared_error = 1.102\nsamples = 7\nvalue = 65.429'),
#  Text(0.5522088353413654, 0.38235294117647056, 'forecast_under <= 73.5\nsquared_error = 0.188\nsamples = 4\nvalue = 66.25'),
#  Text(0.5481927710843374, 0.3235294117647059, 'squared_error = 0.0\nsamples = 3\nvalue = 66.0'),
#  Text(0.5562248995983936, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.5682730923694779, 0.38235294117647056, 'forecast_under <= 80.5\nsquared_error = 0.222\nsamples = 3\nvalue = 64.333'),
#  Text(0.5642570281124498, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 64.0'),
#  Text(0.572289156626506, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.5803212851405622, 0.4411764705882353, 'forecast_acc <= 64.5\nsquared_error = 0.25\nsamples = 2\nvalue = 63.5'),
#  Text(0.5763052208835341, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.5843373493975904, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.5923694779116466, 0.5, 'temp_2 <= 65.5\nsquared_error = 6.25\nsamples = 4\nvalue = 67.5'),
#  Text(0.5883534136546185, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.5963855421686747, 0.4411764705882353, 'forecast_noaa <= 69.5\nsquared_error = 2.889\nsamples = 3\nvalue = 66.333'),
#  Text(0.5923694779116466, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.6004016064257028, 0.38235294117647056, 'temp_2 <= 69.0\nsquared_error = 0.25\nsamples = 2\nvalue = 67.5'),
#  Text(0.5963855421686747, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.6044176706827309, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.5893574297188755, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.6054216867469879, 0.7352941176470589, 'forecast_under <= 63.0\nsquared_error = 14.0\nsamples = 8\nvalue = 69.0'),
#  Text(0.5973895582329317, 0.6764705882352942, 'temp_2 <= 66.0\nsquared_error = 4.0\nsamples = 2\nvalue = 74.0'),
#  Text(0.5933734939759037, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.6014056224899599, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.6134538152610441, 0.6764705882352942, 'forecast_acc <= 69.5\nsquared_error = 6.222\nsamples = 6\nvalue = 67.333'),
#  Text(0.6094377510040161, 0.6176470588235294, 'squared_error = 0.0\nsamples = 2\nvalue = 65.0'),
#  Text(0.6174698795180723, 0.6176470588235294, 'average <= 69.05\nsquared_error = 5.25\nsamples = 4\nvalue = 68.5'),
#  Text(0.6134538152610441, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.6214859437751004, 0.5588235294117647, 'friend <= 71.831\nsquared_error = 1.556\nsamples = 3\nvalue = 69.667'),
#  Text(0.6174698795180723, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.6255020080321285, 0.5, 'temp_2 <= 63.5\nsquared_error = 0.25\nsamples = 2\nvalue = 70.5'),
#  Text(0.6214859437751004, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.6295180722891566, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 70.0'),
#  Text(0.8894523406124498, 0.8529411764705882, 'forecast_acc <= 76.5\nsquared_error = 43.705\nsamples = 99\nvalue = 74.051'),
#  Text(0.828101468373494, 0.7941176470588235, 'month <= 9.5\nsquared_error = 39.657\nsamples = 76\nvalue = 72.618'),
#  Text(0.7643856676706827, 0.7352941176470589, 'temp_1_x <= 76.5\nsquared_error = 34.355\nsamples = 73\nvalue = 73.123'),
#  Text(0.6812562751004017, 0.6764705882352942, 'temp_2 <= 84.0\nsquared_error = 25.702\nsamples = 51\nvalue = 71.941'),
#  Text(0.6772402108433735, 0.6176470588235294, 'average <= 56.7\nsquared_error = 23.308\nsamples = 50\nvalue = 72.18'),
#  Text(0.6495983935742972, 0.5588235294117647, 'average <= 56.1\nsquared_error = 29.188\nsamples = 4\nvalue = 66.75'),
#  Text(0.641566265060241, 0.5, 'month <= 3.5\nsquared_error = 1.0\nsamples = 2\nvalue = 72.0'),
#  Text(0.6375502008032129, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.6455823293172691, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.6576305220883534, 0.5, 'temp_2 <= 68.0\nsquared_error = 2.25\nsamples = 2\nvalue = 61.5'),
#  Text(0.6536144578313253, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.6616465863453815, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.7048820281124498, 0.5588235294117647, 'actual <= 64.5\nsquared_error = 20.009\nsamples = 46\nvalue = 72.652'),
#  Text(0.679718875502008, 0.5, 'temp_2 <= 76.0\nsquared_error = 31.09\nsamples = 10\nvalue = 74.9'),
#  Text(0.6696787148594378, 0.4411764705882353, 'temp_2 <= 62.0\nsquared_error = 24.5\nsamples = 8\nvalue = 76.5'),
#  Text(0.6616465863453815, 0.38235294117647056, 'average <= 64.0\nsquared_error = 31.688\nsamples = 4\nvalue = 73.75'),
#  Text(0.6576305220883534, 0.3235294117647059, 'squared_error = 0.0\nsamples = 3\nvalue = 77.0'),
#  Text(0.6656626506024096, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.677710843373494, 0.38235294117647056, 'temp_1_x <= 75.5\nsquared_error = 2.188\nsamples = 4\nvalue = 79.25'),
#  Text(0.6736947791164659, 0.3235294117647059, 'average <= 65.55\nsquared_error = 0.667\nsamples = 3\nvalue = 80.0'),
#  Text(0.6696787148594378, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 81.0'),
#  Text(0.677710843373494, 0.2647058823529412, 'temp_2 <= 69.5\nsquared_error = 0.25\nsamples = 2\nvalue = 79.5'),
#  Text(0.6736947791164659, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 79.0'),
#  Text(0.6817269076305221, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 80.0'),
#  Text(0.6817269076305221, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.6897590361445783, 0.4411764705882353, 'forecast_noaa <= 66.0\nsquared_error = 6.25\nsamples = 2\nvalue = 68.5'),
#  Text(0.6857429718875502, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.6937751004016064, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.7300451807228916, 0.5, 'average <= 70.45\nsquared_error = 15.138\nsamples = 36\nvalue = 72.028'),
#  Text(0.7058232931726908, 0.4411764705882353, 'forecast_under <= 86.0\nsquared_error = 2.204\nsamples = 7\nvalue = 67.714'),
#  Text(0.7018072289156626, 0.38235294117647056, 'temp_2 <= 70.0\nsquared_error = 0.472\nsamples = 6\nvalue = 67.167'),
#  Text(0.6977911646586346, 0.3235294117647059, 'temp_2 <= 66.0\nsquared_error = 0.188\nsamples = 4\nvalue = 66.75'),
#  Text(0.6937751004016064, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.7018072289156626, 0.2647058823529412, 'squared_error = 0.0\nsamples = 3\nvalue = 67.0'),
#  Text(0.7058232931726908, 0.3235294117647059, 'squared_error = 0.0\nsamples = 2\nvalue = 68.0'),
#  Text(0.7098393574297188, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.7542670682730924, 0.4411764705882353, 'actual <= 67.5\nsquared_error = 12.685\nsamples = 29\nvalue = 73.069'),
#  Text(0.7218875502008032, 0.38235294117647056, 'forecast_noaa <= 73.5\nsquared_error = 3.44\nsamples = 5\nvalue = 76.4'),
#  Text(0.713855421686747, 0.3235294117647059, 'forecast_under <= 84.5\nsquared_error = 0.667\nsamples = 3\nvalue = 75.0'),
#  Text(0.7098393574297188, 0.2647058823529412, 'temp_2 <= 70.5\nsquared_error = 0.25\nsamples = 2\nvalue = 75.5'),
#  Text(0.7058232931726908, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.713855421686747, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.7178714859437751, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.7299196787148594, 0.3235294117647059, 'month <= 7.5\nsquared_error = 0.25\nsamples = 2\nvalue = 78.5'),
#  Text(0.7259036144578314, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 78.0'),
#  Text(0.7339357429718876, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 79.0'),
#  Text(0.7866465863453815, 0.38235294117647056, 'forecast_under <= 79.5\nsquared_error = 11.818\nsamples = 24\nvalue = 72.375'),
#  Text(0.7540160642570282, 0.3235294117647059, 'average <= 71.05\nsquared_error = 8.284\nsamples = 13\nvalue = 70.846'),
#  Text(0.7419678714859438, 0.2647058823529412, 'actual <= 69.0\nsquared_error = 1.0\nsamples = 2\nvalue = 74.0'),
#  Text(0.7379518072289156, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.7459839357429718, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.7660642570281124, 0.2647058823529412, 'average <= 74.5\nsquared_error = 7.471\nsamples = 11\nvalue = 70.273'),
#  Text(0.7540160642570282, 0.20588235294117646, 'temp_2 <= 67.5\nsquared_error = 5.889\nsamples = 6\nvalue = 68.667'),
#  Text(0.75, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.7580321285140562, 0.14705882352941177, 'actual <= 72.5\nsquared_error = 0.24\nsamples = 5\nvalue = 67.6'),
#  Text(0.7540160642570282, 0.08823529411764706, 'forecast_under <= 62.0\nsquared_error = 0.222\nsamples = 3\nvalue = 67.333'),
#  Text(0.75, 0.029411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.7580321285140562, 0.029411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 67.0'),
#  Text(0.7620481927710844, 0.08823529411764706, 'squared_error = 0.0\nsamples = 2\nvalue = 68.0'),
#  Text(0.7781124497991968, 0.20588235294117646, 'forecast_under <= 67.0\nsquared_error = 2.56\nsamples = 5\nvalue = 72.2'),
#  Text(0.7740963855421686, 0.14705882352941177, 'month <= 7.5\nsquared_error = 0.667\nsamples = 3\nvalue = 71.0'),
#  Text(0.7700803212851406, 0.08823529411764706, 'forecast_noaa <= 78.5\nsquared_error = 0.25\nsamples = 2\nvalue = 71.5'),
#  Text(0.7660642570281124, 0.029411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.7740963855421686, 0.029411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.7781124497991968, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 70.0'),
#  Text(0.7821285140562249, 0.14705882352941177, 'squared_error = 0.0\nsamples = 2\nvalue = 74.0'),
#  Text(0.8192771084337349, 0.3235294117647059, 'month <= 7.5\nsquared_error = 9.967\nsamples = 11\nvalue = 74.182'),
#  Text(0.8082329317269076, 0.2647058823529412, 'average <= 74.0\nsquared_error = 7.0\nsamples = 8\nvalue = 73.0'),
#  Text(0.7981927710843374, 0.20588235294117646, 'forecast_acc <= 72.5\nsquared_error = 6.96\nsamples = 5\nvalue = 71.8'),
#  Text(0.7901606425702812, 0.14705882352941177, 'month <= 6.5\nsquared_error = 2.25\nsamples = 2\nvalue = 74.5'),
#  Text(0.786144578313253, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.7941767068273092, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.8062248995983936, 0.14705882352941177, 'average <= 73.65\nsquared_error = 2.0\nsamples = 3\nvalue = 70.0'),
#  Text(0.8022088353413654, 0.08823529411764706, 'squared_error = 0.0\nsamples = 2\nvalue = 71.0'),
#  Text(0.8102409638554217, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.8182730923694779, 0.20588235294117646, 'average <= 74.65\nsquared_error = 0.667\nsamples = 3\nvalue = 75.0'),
#  Text(0.8142570281124498, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.822289156626506, 0.14705882352941177, 'actual <= 73.0\nsquared_error = 0.25\nsamples = 2\nvalue = 74.5'),
#  Text(0.8182730923694779, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.8263052208835341, 0.08823529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.8303212851405622, 0.2647058823529412, 'month <= 8.5\nsquared_error = 4.222\nsamples = 3\nvalue = 77.333'),
#  Text(0.8263052208835341, 0.20588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 80.0'),
#  Text(0.8343373493975904, 0.20588235294117646, 'forecast_under <= 86.5\nsquared_error = 1.0\nsamples = 2\nvalue = 76.0'),
#  Text(0.8303212851405622, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.8383534136546185, 0.14705882352941177, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.6852723393574297, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.8475150602409639, 0.6764705882352942, 'temp_2 <= 71.5\nsquared_error = 43.663\nsamples = 22\nvalue = 75.864'),
#  Text(0.8112449799196787, 0.6176470588235294, 'forecast_under <= 40.0\nsquared_error = 28.16\nsamples = 5\nvalue = 81.2'),
#  Text(0.8072289156626506, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 89.0'),
#  Text(0.8152610441767069, 0.5588235294117647, 'average <= 67.65\nsquared_error = 16.188\nsamples = 4\nvalue = 79.25'),
#  Text(0.8072289156626506, 0.5, 'actual <= 61.0\nsquared_error = 0.25\nsamples = 2\nvalue = 75.5'),
#  Text(0.8032128514056225, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.8112449799196787, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.8232931726907631, 0.5, 'temp_1_x <= 79.0\nsquared_error = 4.0\nsamples = 2\nvalue = 83.0'),
#  Text(0.8192771084337349, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 85.0'),
#  Text(0.8273092369477911, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 81.0'),
#  Text(0.883785140562249, 0.6176470588235294, 'temp_1_x <= 88.0\nsquared_error = 37.384\nsamples = 17\nvalue = 74.294'),
#  Text(0.8679718875502008, 0.5588235294117647, 'temp_1_x <= 81.5\nsquared_error = 28.729\nsamples = 15\nvalue = 73.067'),
#  Text(0.8483935742971888, 0.5, 'average <= 65.55\nsquared_error = 16.16\nsamples = 10\nvalue = 74.8'),
#  Text(0.8353413654618473, 0.4411764705882353, 'forecast_under <= 74.0\nsquared_error = 4.667\nsamples = 3\nvalue = 80.0'),
#  Text(0.8313253012048193, 0.38235294117647056, 'friend <= 67.636\nsquared_error = 0.25\nsamples = 2\nvalue = 81.5'),
#  Text(0.8273092369477911, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 81.0'),
#  Text(0.8353413654618473, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 82.0'),
#  Text(0.8393574297188755, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.8614457831325302, 0.4411764705882353, 'month <= 8.5\nsquared_error = 4.531\nsamples = 7\nvalue = 72.571'),
#  Text(0.8514056224899599, 0.38235294117647056, 'temp_1_x <= 79.5\nsquared_error = 2.24\nsamples = 5\nvalue = 73.6'),
#  Text(0.8433734939759037, 0.3235294117647059, 'actual <= 69.5\nsquared_error = 0.222\nsamples = 3\nvalue = 74.667'),
#  Text(0.8393574297188755, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.8473895582329317, 0.2647058823529412, 'squared_error = 0.0\nsamples = 2\nvalue = 75.0'),
#  Text(0.8594377510040161, 0.3235294117647059, 'temp_2 <= 77.0\nsquared_error = 1.0\nsamples = 2\nvalue = 72.0'),
#  Text(0.8554216867469879, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.8634538152610441, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.8714859437751004, 0.38235294117647056, 'temp_2 <= 75.5\nsquared_error = 1.0\nsamples = 2\nvalue = 70.0'),
#  Text(0.8674698795180723, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.8755020080321285, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.8875502008032129, 0.5, 'average <= 72.85\nsquared_error = 35.84\nsamples = 5\nvalue = 69.6'),
#  Text(0.8835341365461847, 0.4411764705882353, 'average <= 62.65\nsquared_error = 17.188\nsamples = 4\nvalue = 67.25'),
#  Text(0.8795180722891566, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.8875502008032129, 0.38235294117647056, 'temp_2 <= 81.5\nsquared_error = 2.667\nsamples = 3\nvalue = 65.0'),
#  Text(0.8835341365461847, 0.3235294117647059, 'forecast_under <= 74.0\nsquared_error = 1.0\nsamples = 2\nvalue = 64.0'),
#  Text(0.8795180722891566, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.8875502008032129, 0.2647058823529412, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.891566265060241, 0.3235294117647059, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.891566265060241, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 79.0'),
#  Text(0.8995983935742972, 0.5588235294117647, 'temp_2 <= 79.0\nsquared_error = 6.25\nsamples = 2\nvalue = 83.5'),
#  Text(0.8955823293172691, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 81.0'),
#  Text(0.9036144578313253, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 86.0'),
#  Text(0.8918172690763052, 0.7352941176470589, 'forecast_acc <= 54.0\nsquared_error = 11.556\nsamples = 3\nvalue = 60.333'),
#  Text(0.8878012048192772, 0.6764705882352942, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.8958333333333334, 0.6764705882352942, 'forecast_noaa <= 62.0\nsquared_error = 1.0\nsamples = 2\nvalue = 58.0'),
#  Text(0.8918172690763052, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.8998493975903614, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.9508032128514057, 0.7941176470588235, 'temp_1_x <= 79.5\nsquared_error = 27.909\nsamples = 23\nvalue = 78.783'),
#  Text(0.9236947791164659, 0.7352941176470589, 'month <= 7.5\nsquared_error = 13.956\nsamples = 15\nvalue = 76.333'),
#  Text(0.9156626506024096, 0.6764705882352942, 'average <= 77.35\nsquared_error = 10.122\nsamples = 7\nvalue = 78.857'),
#  Text(0.9116465863453815, 0.6176470588235294, 'average <= 76.05\nsquared_error = 5.139\nsamples = 6\nvalue = 79.833'),
#  Text(0.9076305220883534, 0.5588235294117647, 'squared_error = 0.0\nsamples = 2\nvalue = 77.0'),
#  Text(0.9156626506024096, 0.5588235294117647, 'actual <= 75.5\nsquared_error = 1.688\nsamples = 4\nvalue = 81.25'),
#  Text(0.9116465863453815, 0.5, 'forecast_under <= 72.5\nsquared_error = 0.25\nsamples = 2\nvalue = 82.5'),
#  Text(0.9076305220883534, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 82.0'),
#  Text(0.9156626506024096, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 83.0'),
#  Text(0.9196787148594378, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 80.0'),
#  Text(0.9196787148594378, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.9317269076305221, 0.6764705882352942, 'actual <= 73.5\nsquared_error = 6.859\nsamples = 8\nvalue = 74.125'),
#  Text(0.927710843373494, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 80.0'),
#  Text(0.9357429718875502, 0.6176470588235294, 'average <= 77.05\nsquared_error = 2.204\nsamples = 7\nvalue = 73.286'),
#  Text(0.9317269076305221, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.9397590361445783, 0.5588235294117647, 'average <= 77.25\nsquared_error = 1.139\nsamples = 6\nvalue = 72.833'),
#  Text(0.9317269076305221, 0.5, 'forecast_under <= 79.5\nsquared_error = 0.188\nsamples = 4\nvalue = 72.25'),
#  Text(0.927710843373494, 0.4411764705882353, 'temp_2 <= 76.0\nsquared_error = 0.25\nsamples = 2\nvalue = 72.5'),
#  Text(0.9236947791164659, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.9317269076305221, 0.38235294117647056, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.9357429718875502, 0.4411764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 72.0'),
#  Text(0.9477911646586346, 0.5, 'temp_1_x <= 75.0\nsquared_error = 1.0\nsamples = 2\nvalue = 74.0'),
#  Text(0.9437751004016064, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.9518072289156626, 0.4411764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.9779116465863453, 0.7352941176470589, 'temp_2 <= 83.5\nsquared_error = 21.734\nsamples = 8\nvalue = 83.375'),
#  Text(0.963855421686747, 0.6764705882352942, 'forecast_under <= 72.0\nsquared_error = 14.16\nsamples = 5\nvalue = 85.8'),
#  Text(0.9598393574297188, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 79.0'),
#  Text(0.9678714859437751, 0.6176470588235294, 'temp_1_x <= 84.0\nsquared_error = 3.25\nsamples = 4\nvalue = 87.5'),
#  Text(0.9598393574297188, 0.5588235294117647, 'forecast_acc <= 77.5\nsquared_error = 1.0\nsamples = 2\nvalue = 86.0'),
#  Text(0.9558232931726908, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 87.0'),
#  Text(0.963855421686747, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 85.0'),
#  Text(0.9759036144578314, 0.5588235294117647, 'forecast_noaa <= 79.5\nsquared_error = 1.0\nsamples = 2\nvalue = 89.0'),
#  Text(0.9718875502008032, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.9799196787148594, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 88.0'),
#  Text(0.9919678714859438, 0.6764705882352942, 'temp_1_x <= 89.0\nsquared_error = 8.222\nsamples = 3\nvalue = 79.333'),
#  Text(0.9879518072289156, 0.6176470588235294, 'temp_1_x <= 84.5\nsquared_error = 2.25\nsamples = 2\nvalue = 77.5'),
#  Text(0.9839357429718876, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 79.0'),
#  Text(0.9919678714859438, 0.5588235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.9959839357429718, 0.6176470588235294, 'squared_error = 0.0\nsamples = 1\nvalue = 83.0')]

# %%
plt.figure(figsize=(10,10))
sklearn.tree.plot_tree(tree_clf,
               feature_names=iris.feature_names[2:],
               class_names=iris.target_names,
               filled = True);

# %%
plt.figure(figsize=(20,30))

# SI LO HABEIS HECHO BIEN, ENTENDEREIS PORQUE USAMOS max_depth PARA CAMBIAR la profundidad de la visualización

# %% [markdown]
# ### 7. Modifica el max_depth a 3 y vuelve a entrenarlo

# %%
import sklearn.tree 

# X_train.
# df3 = df2.drop("temp_1_y", axis = 1)
# df4 = df2
X = X_train # petal length and width
y = y_train

tree_clf = DecisionTreeRegressor(max_depth=3,
                                  random_state=42)
tree_clf.fit(X, y)
plt.figure(figsize=(10,10))
sklearn.tree.plot_tree(tree_clf,
               feature_names=dtr.feature_names_in_,
               class_names=True,
               filled = True)
# Out:
# [Text(0.5, 0.875, 'temp_1_x <= 59.5\nsquared_error = 138.218\nsamples = 278\nvalue = 62.342'),
#  Text(0.25, 0.625, 'average <= 46.85\nsquared_error = 43.932\nsamples = 116\nvalue = 51.414'),
#  Text(0.125, 0.375, 'temp_1_x <= 44.5\nsquared_error = 19.984\nsamples = 32\nvalue = 43.375'),
#  Text(0.0625, 0.125, 'squared_error = 10.055\nsamples = 17\nvalue = 41.059'),
#  Text(0.1875, 0.125, 'squared_error = 18.267\nsamples = 15\nvalue = 46.0'),
#  Text(0.375, 0.375, 'temp_1_x <= 55.5\nsquared_error = 19.059\nsamples = 84\nvalue = 54.476'),
#  Text(0.3125, 0.125, 'squared_error = 10.728\nsamples = 54\nvalue = 52.444'),
#  Text(0.4375, 0.125, 'squared_error = 13.249\nsamples = 30\nvalue = 58.133'),
#  Text(0.75, 0.625, 'temp_1_x <= 67.5\nsquared_error = 58.991\nsamples = 162\nvalue = 70.167'),
#  Text(0.625, 0.375, 'average <= 60.8\nsquared_error = 22.059\nsamples = 63\nvalue = 64.063'),
#  Text(0.5625, 0.125, 'squared_error = 16.974\nsamples = 27\nvalue = 61.37'),
#  Text(0.6875, 0.125, 'squared_error = 16.354\nsamples = 36\nvalue = 66.083'),
#  Text(0.875, 0.375, 'forecast_acc <= 76.5\nsquared_error = 43.705\nsamples = 99\nvalue = 74.051'),
#  Text(0.8125, 0.125, 'squared_error = 39.657\nsamples = 76\nvalue = 72.618'),
#  Text(0.9375, 0.125, 'squared_error = 27.909\nsamples = 23\nvalue = 78.783')]

# %% [markdown]
# ### 8. Vuelve a evaluar tu modelo

# %%
y_pred = tree_clf.predict(X_test)
print("Coeficiente determinación", r2_score(y_test, y_pred))
print("MAE", mean_absolute_error(y_test, y_pred))
print("MAPE", mean_absolute_percentage_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coeficiente determinación 0.6761264785213036
# MAE 5.142857142857143
# MAPE 0.08167108436560193
# MSE 45.285714285714285
# RMSE 6.729466121893644

# %%
y_pred = ....
print("Coeficiente determinación", r2_score(y_test, y_pred))
print("MAE", mean_absolute_error(y_test, y_pred))
print("MAPE", mean_absolute_percentage_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coeficiente determinación 0.7608677663462975
# MAE 4.424444494299118
# MAPE 0.06938377135428464
# MSE 33.43673777437395
# RMSE 5.782450844959596

# %% [markdown]
# ### 9. Vuelve a representar su árbol

# %%
plt.figure(figsize=(15,15))
tree_clf = DecisionTreeRegressor(max_depth=3,
                                  random_state=42)
tree_clf.fit(X, y)

plt.figure(figsize=(10,10))
sklearn.tree.plot_tree(tree_clf,
               feature_names=dtr.feature_names_in_,
               class_names=True,
               filled = True)
# Out:
# [Text(0.5, 0.875, 'temp_1_x <= 59.5\nsquared_error = 138.218\nsamples = 278\nvalue = 62.342'),
#  Text(0.25, 0.625, 'average <= 46.85\nsquared_error = 43.932\nsamples = 116\nvalue = 51.414'),
#  Text(0.125, 0.375, 'temp_1_x <= 44.5\nsquared_error = 19.984\nsamples = 32\nvalue = 43.375'),
#  Text(0.0625, 0.125, 'squared_error = 10.055\nsamples = 17\nvalue = 41.059'),
#  Text(0.1875, 0.125, 'squared_error = 18.267\nsamples = 15\nvalue = 46.0'),
#  Text(0.375, 0.375, 'temp_1_x <= 55.5\nsquared_error = 19.059\nsamples = 84\nvalue = 54.476'),
#  Text(0.3125, 0.125, 'squared_error = 10.728\nsamples = 54\nvalue = 52.444'),
#  Text(0.4375, 0.125, 'squared_error = 13.249\nsamples = 30\nvalue = 58.133'),
#  Text(0.75, 0.625, 'temp_1_x <= 67.5\nsquared_error = 58.991\nsamples = 162\nvalue = 70.167'),
#  Text(0.625, 0.375, 'average <= 60.8\nsquared_error = 22.059\nsamples = 63\nvalue = 64.063'),
#  Text(0.5625, 0.125, 'squared_error = 16.974\nsamples = 27\nvalue = 61.37'),
#  Text(0.6875, 0.125, 'squared_error = 16.354\nsamples = 36\nvalue = 66.083'),
#  Text(0.875, 0.375, 'forecast_acc <= 76.5\nsquared_error = 43.705\nsamples = 99\nvalue = 74.051'),
#  Text(0.8125, 0.125, 'squared_error = 39.657\nsamples = 76\nvalue = 72.618'),
#  Text(0.9375, 0.125, 'squared_error = 27.909\nsamples = 23\nvalue = 78.783')]

# %% [markdown]
# ### 10. Obten el `feature_importances` de cada variable en el último modelo

# %%
tree_clf.feature_importances_
# Out:
# array([0.        , 0.        , 0.88020751, 0.09902152, 0.        ,
#        0.        , 0.02077097, 0.        , 0.        ])

# %%
# importancias
# Out:
# array([0.        , 0.        , 0.88020751, 0.09902152, 0.        ,
#        0.        , 0.02077097, 0.        , 0.        ])

# %%
X_train.columns
# Out:
# Index(['month', 'temp_2', 'temp_1_x', 'average', 'forecast_noaa',
#        'forecast_acc', 'forecast_under', 'friend', 'temp_1_y'],
#       dtype='object')

# %%
# columnas de X_train
# Out:
# Index(['month', 'temp_2', 'temp_1_x', 'average', 'forecast_noaa',
#        'forecast_acc', 'forecast_under', 'friend', 'temp_1_y'],
#       dtype='object')

# %%
pd.DataFrame({'features': X_train.columns, 'importances': tree_clf.feature_importances_}).sort_values('importances', ascending=False)
# Out:
#          features  importances
# 2        temp_1_x     0.880208
# 3         average     0.099022
# 6  forecast_under     0.020771
# 0           month     0.000000
# 1          temp_2     0.000000
# 4   forecast_noaa     0.000000
# 5    forecast_acc     0.000000
# 7          friend     0.000000
# 8        temp_1_y     0.000000

# %% [markdown]
# FIJAOS QUE SOLO USA 3 COLUMNAS...

# %%
# repetimos train test split pero solo nos quedamos las columnas que sirven para algo ['temp_1_x','average','forecast_under']

# %%
dtr_3 = ...
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
print("Coeficiente determinación", r2_score(y_test, y_pred))
print("MAE", mean_absolute_error(y_test, y_pred))
print("MAPE", mean_absolute_percentage_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coeficiente determinación 0.7608677663462975
# MAE 4.424444494299118
# MAPE 0.06938377135428464
# MSE 33.43673777437395
# RMSE 5.782450844959596

# %% [markdown]
# ### 11. Construye un nuevo modelo `DecisionTreeClassifier` que te clasifique cuando en un día no va a hacer una temperatura máxima a 15ºC

# %% [markdown]
# VAMOS A TRANSFORMAR UN PROBLEMA DE REGRESION EN CLASIFICACION. GENERAREMOS UNA CLASE DONDE PONDREMOS 1 SI LA TEMPERATURA PASA DE 59 (GRADOS FAHRENHEIT), Y SI NO 0.

# %%
df['target_clas'] = np.where(df['actual']>59,1,0)
df[['actual','target_clas']].head()
# Out:
#    actual  target_clas
# 0      45            0
# 1      44            0
# 2      41            0
# 3      40            0
# 4      44            0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df['target_clas'].value_counts()
# Out:
# 1    204
# 0    144
# Name: target_clas, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['year','day','week','actual','target_clas']), df['target_clas'], test_size=0.2, random_state=42)

# %%
# ENRTRENA UN MODELO DE CLASIFICACION LLAMADO dtc
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
X_train.columns
# Out:
# Index(['month', 'temp_2', 'temp_1_x', 'average', 'forecast_noaa',
#        'forecast_acc', 'forecast_under', 'friend', 'temp_1_y'],
#       dtype='object')

# %%
# dtc feature importance
# Out:
# array([0.        , 0.        , 0.08751759, 0.83792502, 0.05793051,
#        0.        , 0.01076818, 0.0058587 , 0.        ])

# %%
# accuracy de dtc en test
# Out:
# 0.9

# %%
plt.figure(figsize=(15,15))

plot_tree(dtc, feature_names = X_train.columns, class_names = 'actual', fontsize=10); #max_depth cambia la profundidad de la visualización

# %% [markdown]
# COMPARA LA ACCURACY CON UN LOGISTIC REGRESSOR A PELO

# %%
from sklearn.linear_model import LogisticRegression

# lr
# lr.fit
# accuracy_acore(..., ...)
# Out:
# C:\Users\Miguel Angel\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.8428571428571429

# %%
sns.pairplot(df[['temp_1_x','average','forecast_under','target_clas']], hue='target_clas')

# %% [markdown]
# ### 12. BONUS TRACK: Repite el experimEnto con un un nuevo modelo `RandomForestClassifier` . A lo facil

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = ...
# Out:
# RandomForestClassifier(max_depth=3)

# %%
accuracy_score(y_test,rfc.predict(X_test))
# Out:
# 0.9428571428571428
