# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler


# Load the training and test datasets
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.Activity.value_counts()
# Out:
# Activity
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: count, dtype: int64

# %%
train_df.shape
# Out:
# (7352, 563)

# %%
# Split the data into features and target
X_train = train_df.drop(["subject", 'Activity'], axis=1)
y_train = train_df['Activity']
X_test = test_df.drop(["subject", 'Activity'], axis=1)
y_test = test_df['Activity']

# Create a MinMaxScaler to scale the feature values between 0 and 1
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both the training and test data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create a random forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=0)

# Train the classifier
clf.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test_scaled)

# Calculate the accuracy of the classifier
accuracy = clf.score(X_test_scaled, y_test)

print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.93

# %%
train_df.shape
# Out:
# (7352, 563)

# %%
# import the necessary packages
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
import numpy as np



input_x = keras.Input(shape=(561,))
encoded = Dense(128)(input_x)
encoded = BatchNormalization()(encoded)
encoded = LeakyReLU()(encoded)



encoded = Dense(2, activation="linear")(encoded)



decoded = Dense(128)(encoded)
decoded = BatchNormalization()(decoded)
decoded = LeakyReLU()(decoded)
decoded = Dense(561, activation='sigmoid')(decoded)

# %%
opt = Adam(learning_rate=0.0001)
autoencoder = keras.Model(input_x, decoded)
autoencoder.compile(optimizer="adam", loss='mse')

# %%
autoencoder.fit(X_train_scaled, X_train_scaled,
                epochs=200,
                batch_size=128,
                shuffle=True,
                validation_data=(X_test_scaled, X_test_scaled))
# Out:
# Epoch 1/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0839 - val_loss: 0.0558
# Epoch 2/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - val_loss: 0.0209
# Epoch 3/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - val_loss: 0.0129
# Epoch 4/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088 - val_loss: 0.0104
# Epoch 5/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - val_loss: 0.0092
# Epoch 6/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - val_loss: 0.0079
# Epoch 7/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 8/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 9/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 10/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 11/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 12/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 13/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 14/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 15/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 16/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 17/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 18/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 19/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 20/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 21/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 22/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - val_loss: 0.0076
# Epoch 23/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 24/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 25/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 26/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 27/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 28/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0077
# Epoch 29/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 30/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 31/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 32/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 33/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 34/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 35/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 36/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 37/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 38/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 39/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 40/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 41/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 42/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 43/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 44/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 45/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 46/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 47/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 48/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0074
# Epoch 49/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 50/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 51/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 52/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 53/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 54/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 55/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 56/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 57/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 58/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0071
# Epoch 59/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 60/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0070
# Epoch 61/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - val_loss: 0.0070
# Epoch 62/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 63/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - val_loss: 0.0070
# Epoch 64/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - val_loss: 0.0071
# Epoch 65/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 66/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 67/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0070
# Epoch 68/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - val_loss: 0.0070
# Epoch 69/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 70/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0070
# Epoch 71/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 72/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 73/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 74/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 75/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 76/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 77/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 78/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 79/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 80/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0070
# Epoch 81/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0070
# Epoch 82/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 83/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 84/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 85/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 86/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 87/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 88/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 89/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 90/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 91/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 92/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 93/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 94/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 95/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 96/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 97/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 98/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 99/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 100/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 101/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 102/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 103/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 104/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 105/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 106/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 107/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 108/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 109/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 110/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 111/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 112/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 113/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 114/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 115/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 116/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 117/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 118/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 119/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 120/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 121/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 122/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 123/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 124/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 125/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 126/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 127/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 128/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 129/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 130/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 131/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 132/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 133/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 134/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 135/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 136/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 137/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 138/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 139/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 140/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0071
# Epoch 141/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 142/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 143/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 144/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 145/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 146/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 147/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 148/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 149/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 150/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 151/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 152/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 153/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 154/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 155/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 156/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 157/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 158/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 159/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 160/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 161/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 162/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 163/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 164/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 165/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 166/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 167/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 168/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 169/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 170/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 171/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 172/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 173/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 174/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 175/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 176/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 177/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 178/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 179/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 180/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 181/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 182/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 183/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 184/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 185/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 186/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 187/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 188/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 189/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 190/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 191/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 192/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 193/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 194/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 195/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 196/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 197/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 198/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 199/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 200/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0069

# %%
encoder = Model(inputs=input_x, outputs=encoded)

# %%
X_train_ae = encoder.predict(X_train_scaled)
X_test_ae = encoder.predict(X_test_scaled)
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step

# %%
X_train_ae.shape
# Out:
# (7352, 2)

# %%
x1 = X_train_ae[:, 0]
x2 = X_train_ae[:, 1]

# %%
y_train.value_counts()
# Out:
# Activity
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
ys = LabelEncoder().fit_transform(y_train)

# %%
import matplotlib.pyplot as plt
plt.scatter(x=x1, y=x2, c=ys)

# %%
# Create a random forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=0)

# Train the classifier
clf.fit(X_train_ae, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test_ae)

# Calculate the accuracy of the classifier
accuracy = clf.score(X_test_ae, y_test)

print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.76

# %%
# %history
# Out:
# import pandas as pd
# from sklearn.datasets import load_breast_cancer
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
#
# # Load the dataset
# data = load_breast_cancer()
#
# # Convert to pandas DataFrame
# df = pd.DataFrame(data.data, columns=data.feature_names)
# df['target'] = data.target
#
# # Split the data into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(df[data.feature_names], df['target'], random_state=0)
#
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
#
# # Load the training and test datasets
# train_df = pd.read_csv('train.csv')
# test_df = pd.read_csv('test.csv')
#
# # Split the data into features and target
# X_train = train_df.drop('Activity', axis=1)
# y_train = train_df['Activity']
# X_test = test_df.drop('Activity', axis=1)
# y_test = test_df['Activity']
#
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# train_df.columns
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
#
# # Load the training and test datasets
# train_df = pd.read_csv('train.csv')
# test_df = pd.read_csv('test.csv')
#
# # Split the data into features and target
# X_train = train_df.drop(["Subject", 'Activity'], axis=1)
# y_train = train_df['Activity']
# X_test = test_df.drop(["Subject", 'Activity'], axis=1)
# y_test = test_df['Activity']
#
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
#
# # Load the training and test datasets
# train_df = pd.read_csv('train.csv')
# test_df = pd.read_csv('test.csv')
#
# # Split the data into features and target
# X_train = train_df.drop(["subject", 'Activity'], axis=1)
# y_train = train_df['Activity']
# X_test = test_df.drop(["subject", 'Activity'], axis=1)
# y_test = test_df['Activity']
#
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# train_df.shape
# # import the necessary packages
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
# input_x = keras.Input(shape=(563,))
# encoded = layers.Dense(128, activation='relu')(input_img)
# encoded = layers.Dense(64, activation='relu')(encoded)
# encoded = layers.Dense(32, activation='relu')(encoded)
#
# decoded = layers.Dense(64, activation='relu')(encoded)
# decoded = layers.Dense(128, activation='relu')(decoded)
# decoded = layers.Dense(784, activation='sigmoid')(decoded)
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
#
# # Load the training and test datasets
# train_df = pd.read_csv('train.csv')
# test_df = pd.read_csv('test.csv')
#
# # Split the data into features and target
# X_train = train_df.drop(["subject", 'Activity'], axis=1)
# y_train = train_df['Activity']
# X_test = test_df.drop(["subject", 'Activity'], axis=1)
# y_test = test_df['Activity']
#
# # Create a MinMaxScaler to scale the feature values between 0 and 1
# scaler = MinMaxScaler()
#
# # Fit the scaler on the training data and transform both the training and test data
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
#
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train_scaled, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test_scaled)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test_scaled, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.preprocessing import MinMaxScaler
#
#
# # Load the training and test datasets
# train_df = pd.read_csv('train.csv')
# test_df = pd.read_csv('test.csv')
#
# # Split the data into features and target
# X_train = train_df.drop(["subject", 'Activity'], axis=1)
# y_train = train_df['Activity']
# X_test = test_df.drop(["subject", 'Activity'], axis=1)
# y_test = test_df['Activity']
#
# # Create a MinMaxScaler to scale the feature values between 0 and 1
# scaler = MinMaxScaler()
#
# # Fit the scaler on the training data and transform both the training and test data
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
#
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train_scaled, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test_scaled)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test_scaled, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# # import the necessary packages
# from tensorflow inport keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(563,))
# encoded = Dense(128, activation='relu')(input_img)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# decoded = Dense(128, activation='relu')(decoded)
# decoded = Dense(563, activation='sigmoid')(decoded)
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(563,))
# encoded = Dense(128, activation='relu')(input_img)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# decoded = Dense(128, activation='relu')(decoded)
# decoded = Dense(563, activation='sigmoid')(decoded)
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(563,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# decoded = Dense(128, activation='relu')(decoded)
# decoded = Dense(563, activation='sigmoid')(decoded)
# autoencoder = keras.Model(input_img, decoded)
# autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
#
# autoencoder.fit(x_train, x_train,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(x_test, x_test))
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
#
# autoencoder.fit(x_train, x_train,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(x_test, x_test))
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# decoded = Dense(128, activation='relu')(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(x)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(x)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(x)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(x)
# decoded = Dense(561, activation='sigmoid')(decoded)
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(x)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(x)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(x)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(x)
# decoded = Dense(561, activation='sigmoid')(decoded)
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 validation_data=(X_test_scaled, X_test_scaled))
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer=Adam, loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer=opt, loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-1)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer=opt, loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-3)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer=opt, loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=50,
#                 batch_size=32,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer=opt, loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=50,
#                 batch_size=64,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=50,
#                 batch_size=412,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(561, activation='linear')(decoded)
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=50,
#                 batch_size=412,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='binary_crossentropy')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-2)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer=opt, loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# opt = Adam(learning_rate=1e-3)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer=opt, loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(561, activation='linear')(decoded)
# opt = Adam(learning_rate=1e-3)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(32, activation='relu')(encoded)
#
# decoded = Dense(64, activation='relu')(encoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(128, activation='relu')(decoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# opt = Adam(learning_rate=1e-3)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# autoencoder.summary)()
# autoencoder.summary()
# auto_encoder.get_layer('dense_47')
# autoencoder.get_layer('dense_47')
# autoencoder.get_layer('dense_47').predict(X_train_scaled)
# encoder = Model(inputs=input_x, outputs=encoded)
# encoder.predict(X_train_scaled)
# X_train_ae = encoder.predict(X_train_scaled)
# X_test_ae = encoder.predict(X_test_scaled)
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train_ae, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test_ae)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test_ae, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128, activation='relu')(input_x)
# encoded = Dropout(0.3)(encoded)
# encoded = Dense(64, activation='relu')(encoded)
#
# decoded = Dense(128, activation='relu')(encoded)
# encoded = Dropout(0.3)(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# opt = Adam(learning_rate=1e-3)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# encoder = Model(inputs=input_x, outputs=encoded)
# X_train_ae = encoder.predict(X_train_scaled)
# X_test_ae = encoder.predict(X_test_scaled)
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train_ae, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test_ae)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test_ae, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(128)(input_x)
# encoded = BatchNormalization()(encoded)
# encoded = LeakyReLU()(encoded)
# encoded = Dense(64, activation="sigmoid")(encoded)
#
# decoded = Dense(128)(encoded)
# decoded = BatchNormalization()(decoded)
# decoded = LeakyReLU()(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# opt = Adam(learning_rate=1e-3)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# encoder = Model(inputs=input_x, outputs=encoded)
# X_train_ae = encoder.predict(X_train_scaled)
# X_test_ae = encoder.predict(X_test_scaled)
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train_ae, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test_ae)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test_ae, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# # import the necessary packages
# from tensorflow import keras
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import Conv2D
# from tensorflow.keras.layers import Conv2DTranspose
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import Activation
# from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.layers import Reshape
# from tensorflow.keras.layers import Input
# from tensorflow.keras.models import Model
# from tensorflow.keras import backend as K
# from tensorflow.keras.optimizers import Adam
# import numpy as np
#
#
#
# input_x = keras.Input(shape=(561,))
# encoded = Dense(256)(input_x)
# encoded = BatchNormalization()(encoded)
# encoded = LeakyReLU()(encoded)
# encoded = Dense(128, activation="sigmoid")(encoded)
#
# decoded = Dense(256)(encoded)
# decoded = BatchNormalization()(decoded)
# decoded = LeakyReLU()(decoded)
# decoded = Dense(561, activation='sigmoid')(decoded)
# opt = Adam(learning_rate=1e-3)
# autoencoder = keras.Model(input_x, decoded)
# autoencoder.compile(optimizer="adam", loss='mse')
#
# autoencoder.fit(X_train_scaled, X_train_scaled,
#                 epochs=100,
#                 batch_size=256,
#                 shuffle=True,
#                 validation_data=(X_test_scaled, X_test_scaled))
# encoder = Model(inputs=input_x, outputs=encoded)
# X_train_ae = encoder.predict(X_train_scaled)
# X_test_ae = encoder.predict(X_test_scaled)
# # Create a random forest classifier
# clf = RandomForestClassifier(n_estimators=100, random_state=0)
#
# # Train the classifier
# clf.fit(X_train_ae, y_train)
#
# # Make predictions on the test set
# y_pred = clf.predict(X_test_ae)
#
# # Calculate the accuracy of the classifier
# accuracy = clf.score(X_test_ae, y_test)
#
# print(f'Accuracy: {accuracy:.2f}')
# %history
